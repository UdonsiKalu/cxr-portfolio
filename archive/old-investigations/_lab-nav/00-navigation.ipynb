# %% [markdown]
# <div style="background:#eef4ff;border-left:4px solid #0550ae;padding:12px 16px;">
#   <strong>Run this cell (Shift+Enter)</strong> for blue clickable links.
# </div>
#
# # CXR Investigations — Navigation
#
# <div style="background:#f6f8fa;padding:12px 16px;border-radius:8px;">
#   <h3 style="margin-top:0;">Start</h3>
#   <ul>
#     <li><a href="README.ipynb"><b>Investigations index</b></a></li>
#     <li><a href="template-investigation.ipynb"><b>New study template</b></a></li>
#     <li><a href="lab-navigation.html"><b>HTML index (browser)</b></a></li>
#     <li><a href="../README.ipynb"><b>Portfolio home</b></a></li>
#   </ul>
#   <h3>Completed</h3>
#   <ul>
#     <li><a href="latency-investigation/notebook.ipynb">Claim analysis latency</a></li>
#     <li><a href="load-testing/notebook.ipynb">Locust load baseline</a></li>
#     <li><a href="cold-vs-warm-analyzer/notebook.ipynb">PERF-004 — cold vs warm</a></li>
#     <li><a href="ci-pipeline/notebook.ipynb">CI-001</a></li>
#   </ul>
#   <h3>Phase 2</h3>
#   <ul>
#     <li><a href="planned/platform-bootstrap.ipynb">Platform bootstrap</a></li>
#     <li><a href="planned/kubernetes-migration.ipynb">Kubernetes migration</a></li>
#     <li><a href="planned/notebook.ipynb">Full backlog</a></li>
#   </ul>
# </div>
