# %% [markdown]
# <div style="background:#eef4ff;border-left:4px solid #0550ae;padding:12px 16px;margin-bottom:16px;">
#   <strong>Run this cell (Shift+Enter)</strong> for blue clickable links.<br/>
#   Edit this <code>.ipynb</code> only — not <code>.md</code>.
# </div>
#
# # Investigation title (ID-XXX)
#
# | | |
# |---|---|
# | **Status** | Planned / In progress / Complete |
# | **ID** | e.g. K8-002, LOAD-003 |
# | **Environment** | `cxr up`, kind `:8081`, CI only |
#
# <div style="background:#f6f8fa;padding:12px 16px;border-radius:8px;">
#   <h3 style="margin-top:0;">🔗 Navigation</h3>
#   <ul>
#     <li><a href="00-navigation.ipynb"><b>All investigations</b></a></li>
#     <li><a href="lab-navigation.html"><b>HTML index (browser)</b></a></li>
#     <li><a href="../README.ipynb"><b>Portfolio home</b></a></li>
#     <li><a href="kubernetes-deploy/notebook.ipynb"><b>Example: K8-001</b></a></li>
#     <li><a href="ci-pipeline/notebook.ipynb"><b>Example: CI-001</b></a></li>
#   </ul>
# </div>
#
# > Copy to `<your-study>/notebook.ipynb` — one notebook per investigation folder.

# %% [markdown]
# ## Question
#
# One clear sentence: what are we trying to learn?

# %% [markdown]
# ## Hypothesis
#
# What we expect before running.

# %% [markdown]
# ## Environment
#
# | Item | Value |
# |------|--------|
# | Stack | `cxr up` / `03-k8-stack-up.sh` |
# | Ports | `:8251` UI, `:8766` analyzer, `:8081` K8 |
# | Commit | optional git SHA |

# %%
# Quick environment check (Python kernel — use ! for shell)
# !curl -sf http://127.0.0.1:8766/health 2>/dev/null | head -c 200 || echo "analyzer :8766 not up"

# %% [markdown]
# ## Commands run
#
# Paste commands or use code cells below.

# %%
# Example: kubectl snapshot
# !kubectl get all -n cxr-ui 2>/dev/null || echo "kind stack not running"

# %% [markdown]
# ## Scripts used
#
# - `cxr-ops-lab/scripts/03-k8-stack-up.sh` — register in [../scripts/README.md](../scripts/README.md)
#
# ## Results
#
# Output, metrics, screenshots path (`screenshots/`, `results/`).
#
# ## Findings
#
# What we learned.
#
# ## Decision
#
# Ship / defer / follow-up.
